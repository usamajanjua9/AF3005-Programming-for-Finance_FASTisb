# %% [markdown]
# # **📌 Week 9: Data Visualization**
# 📍 **FAST-NUCES, Islamabad**
# 👨‍🏫 **Instructor:** Dr. Usama Arshad (Assistant Professor, FSM)
# 📅 **Semester:** Spring 2025
#
# ---
# ## **🟢 1. Introduction to Data Visualization**
#
# ### **🔹 What is Data Visualization?**
# - **Definition:** Data visualization is the graphical representation of information and data.
# - **Purpose:** It allows users to identify patterns, trends, and insights that may not be apparent from raw data.
# - **Types of Data Visualization:**
#   - Static (e.g., Matplotlib, Seaborn)
#   - Interactive (e.g., Plotly, Dash)
#
# ---
#
# <img src="https://bs-uploads.toptal.io/blackfish-uploads/public-files/22-PUB-MobileData-Multigif-v1-573fc723862d2ab6c57d4bb497dcc642.gif" width="500">
#
# ---
# ### **🔹 Importance of Visualization in Finance**
# - **Improves Decision Making:** Helps analysts and investors make data-driven decisions.
# - **Identifies Trends and Patterns:** Detects stock market trends, volatility, and seasonality.
# - **Risk Assessment:** Helps in understanding asset correlations and risk exposure.
# - **Performance Comparison:** Enables comparisons of stock performance, investment returns, and financial ratios.
# - **Effective Communication:** Simplifies complex financial data for reports, presentations, and dashboards.
#
# ---
#
# ### **🔹 Common Financial Visualizations and Their Use Cases**
# | **Visualization Type**  | **Use Case in Finance** |
# |----------------------|------------------------|
# | **Line Charts** | Stock price trends over time, moving averages |
# | **Bar Charts** | Revenue comparisons across companies/sectors |
# | **Scatter Plots** | Correlation between two financial metrics (e.g., revenue vs. profit) |
# | **Histograms** | Stock price distribution, risk assessment |
# | **Box Plots** | Detecting outliers in asset prices or returns |
# | **Heatmaps** | Correlation matrix of multiple assets/stocks |
# | **Candlestick Charts** | Price movement analysis in trading (OHLC data) |
#
# ---
#
#
# ![output.png](data:image/png;base64,...)
#
# ---
#
# ### **🔹 Overview of Popular Python Visualization Libraries**
#
# #### **📌 Matplotlib**
# - **General-purpose plotting library** in Python.
# - **Highly customizable** but requires more effort for styling.
# - **Works well for static plots** like **line charts, bar charts, and histograms**.
# - **Commonly used in financial modeling and reporting**.
#
# #### **📌 Seaborn**
# - **Built on top of Matplotlib**, providing more elegant and informative visualizations.
# - **Uses themes and color palettes for aesthetics**.
# - **Ideal for complex financial data analysis** with **heatmaps, box plots, and pair plots**.
#
# #### **📌 Plotly (Brief comparison)**
# - **Designed for interactive visualizations**.
# - **Used for dashboards, real-time data visualization, and dynamic stock market analysis**.
# - **More suitable for web applications and user-driven exploration** (e.g., Dash framework).
# - **Not covered in-depth in this week, focus on Matplotlib & Seaborn**.
#
# ---
#
# ### **🔹 Key Differences Between Matplotlib and Seaborn**
#
# | **Feature**  | **Matplotlib** | **Seaborn** |
# |-------------|--------------|-------------|
# | **Ease of Use** | Requires manual styling | Default themes and styles |
# | **Customization** | Highly customizable | Limited but elegant visuals |
# | **Best For** | General plotting | Statistical & financial analysis |
# | **Performance** | Faster for simple plots | Slightly slower due to built-in aesthetics |
# | **Data Handling** | Requires manual processing | Works seamlessly with Pandas DataFrames |
# | **Common Use Cases** | Stock trends, histograms, revenue bar charts | Heatmaps, pair plots, risk analysis |
#
#
# ---
#
# ## **🔹 Summary**
# - Data visualization helps analyze financial trends, assess risks, and compare performance.
# - Matplotlib is **flexible and detailed** but requires customization.
# - Seaborn is **easy to use** with built-in styles for financial insights.
# - **Plotly is not covered this week**, but it is useful for interactive dashboards.
#
# ---

# %% [markdown]
# ## **🟢 2. Getting Started with Matplotlib**
#
# ---
#
# ## **🔹 Installing and Importing Matplotlib**
# Matplotlib is a **widely used** data visualization library in Python.
#
# ### **📌 Installing Matplotlib**
# If not already installed, use the following command:
# ```python
# !pip install matplotlib
# ```
#
# Documentation: https://matplotlib.org/stable/index.html
#
# ### **📌 Importing Matplotlib**
# ```python
# import matplotlib.pyplot as plt  # Importing pyplot for plotting
# ```
#
# - `pyplot` is a **module in Matplotlib** that provides a **MATLAB-like interface** for visualization.
# - It allows you to **quickly create** simple **line charts, bar plots, scatter plots, and histograms**.
#
# ---
#
# ## **🔹 Understanding Basic Components of a Plot**
# Matplotlib **figures** consist of multiple elements:
#
# | **Component** | **Description** |
# |--------------|----------------|
# | **Figure** | The entire plotting area (background of the chart). |
# | **Axes** | The actual area where the data is plotted (X and Y axis). |
# | **Title** | Describes what the chart represents. |
# | **Labels** | X-axis and Y-axis descriptions. |
# | **Ticks** | Markings on the X and Y axes for scale. |
# | **Legend** | Explains what different colors or lines represent. |
# | **Grid** | Optional gridlines for reference. |
#
# ---
#
# ## **🔹 Creating a Simple Line Plot Using Matplotlib**
# A **line chart** is commonly used in finance to **show stock price trends** over time.

# %% [markdown]
# ### **📌 Example: Stock Price Trends Over 5 Days**
# ```python
# import matplotlib.pyplot as plt
#
# # Sample stock price data
# days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
# prices = [120, 125, 130, 128, 135]
#
# # Creating a line chart
# plt.plot(days, prices, marker='o', linestyle='-', color='b', label="Stock Price")
#
# # Adding titles and labels
# plt.title("Stock Price Trend Over the Week")  # Title of the chart
# plt.xlabel("Days")  # X-axis label
# plt.ylabel("Price (USD)")  # Y-axis label
#
# # Adding a legend
# plt.legend()
#
# # Displaying the plot
# plt.show()
# ```
# ### **📌 Output:**
# This will generate a **line plot** showing stock prices over the week.
#
# ✅ **Key Features:**
# - **`marker='o'`** → Adds circular markers to data points.
# - **`linestyle='-'`** → Connects points with a solid line.
# - **`color='b'`** → Uses blue for the line color.
# - **`plt.legend()`** → Displays a legend.
#
# ---

# %% [markdown]
# Run !!

# %%
import matplotlib.pyplot as plt

# Sample stock price data
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
prices = [120, 125, 130, 128, 135]

# Creating a line chart
plt.plot(days, prices, marker='o', linestyle='-', color='b', label="Stock Price")

# Adding titles and labels
plt.title("Stock Price Trend Over the Week")  # Title of the chart
plt.xlabel("Days")  # X-axis label
plt.ylabel("Price (USD)")  # Y-axis label

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %% [markdown]
# ## **🔹 Customizing Plots in Matplotlib**
# Matplotlib allows **extensive customization** of plots.
#
# ### **📌 Modifying Colors, Line Styles, and Markers**
# ```python
# plt.plot(days, prices, marker='s', linestyle='dashed', color='red', label="Stock Price")
# plt.title("Customized Stock Price Trend")
# plt.xlabel("Days")
# plt.ylabel("Price (USD)")
# plt.legend()
# plt.show()
# ```
# ✅ **Changes in this plot:**
# - **`marker='s'`** → Square markers.
# - **`linestyle='dashed'`** → Dashed lines for better visibility.
# - **`color='red'`** → Red line for emphasis.
#
# ---

# %% [markdown]
# Run !!

# %%
plt.plot(days, prices, marker='s', linestyle='dashed', color='red', label="Stock Price")
plt.title("Customized Stock Price Trend")
plt.xlabel("Days")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()

# %% [markdown]
# ## **🔹 Creating a Bar Chart for Financial Comparisons**
# Bar charts are useful for **comparing revenue, profit, or stock performance**.
#
# ### **📌 Example: Comparing Two Stocks**
# ```python
# import numpy as np
#
# # Sample financial data
# days = np.arange(5)
# prices_a = [120, 125, 130, 128, 135]  # Stock A
# prices_b = [115, 118, 125, 127, 132]  # Stock B
#
# # Creating a bar chart
# plt.bar(days - 0.2, prices_a, width=0.4, label="Stock A", color='blue')
# plt.bar(days + 0.2, prices_b, width=0.4, label="Stock B", color='red')
#
# # Adding labels and title
# plt.xticks(days, ["Mon", "Tue", "Wed", "Thu", "Fri"])
# plt.xlabel("Days")
# plt.ylabel("Stock Price (USD)")
# plt.title("Stock Price Comparison")
# plt.legend()
# plt.show()
# ```
# ### **📌 Output:**
# A **grouped bar chart** comparing **Stock A vs. Stock B prices** over the week.
#
# ✅ **Key Features:**
# - **`plt.bar()`** → Creates bar charts.
# - **`width=0.4`** → Adjusts bar size for clarity.
# - **`plt.xticks()`** → Assigns **day labels** to bars.
#
# ---

# %% [markdown]
# Run !!

# %%
import numpy as np

# Sample financial data
days = np.arange(5)
prices_a = [120, 125, 130, 128, 135]  # Stock A
prices_b = [115, 118, 125, 127, 132]  # Stock B

# Creating a bar chart
plt.bar(days - 0.2, prices_a, width=0.4, label="Stock A", color='blue')
plt.bar(days + 0.2, prices_b, width=0.4, label="Stock B", color='red')

# Adding labels and title
plt.xticks(days, ["Mon", "Tue", "Wed", "Thu", "Fri"])
plt.xlabel("Days")
plt.ylabel("Stock Price (USD)")
plt.title("Stock Price Comparison")
plt.legend()
plt.show()

# %% [markdown]
# ## **🔹 Creating a Scatter Plot for Correlation Analysis**
# A **scatter plot** helps analyze **correlation** between **two financial variables**.
#
# ### **📌 Example: Stock Price vs. Trading Volume**
# ```python
# # Sample stock data
# volume = [1000, 1500, 1700, 1300, 2000]  # Trading volume
# prices = [120, 125, 130, 128, 135]  # Stock price
#
# # Creating a scatter plot
# plt.scatter(volume, prices, color='green', marker='o')
#
# # Adding title and labels
# plt.title("Stock Price vs Trading Volume")
# plt.xlabel("Trading Volume")
# plt.ylabel("Stock Price (USD)")
# plt.show()
# ```
# ✅ **Use Case:**
# - Helps **determine if stock price increases with high trading volume**.
#
# ---

# %% [markdown]
# Run !!

# %%
# Sample stock data
volume = [1000, 1500, 1700, 1300, 2000]  # Trading volume
prices = [120, 125, 130, 128, 135]  # Stock price

# Creating a scatter plot
plt.scatter(volume, prices, color='green', marker='o')

# Adding title and labels
plt.title("Stock Price vs Trading Volume")
plt.xlabel("Trading Volume")
plt.ylabel("Stock Price (USD)")
plt.show()

# %% [markdown]
# ## **🔹 Handling Date-Based Financial Data**
# Financial data is often **time-based (dates as X-axis values)**.
#
# ### **📌 Example: Plotting a Time-Series Stock Chart**
# ```python
# import matplotlib.dates as mdates
# import datetime
#
# # Sample stock data with dates
# dates = [datetime.date(2023, 1, i) for i in range(1, 6)]
# prices = [120, 125, 130, 128, 135]
#
# plt.figure(figsize=(8,5))  # Set figure size
# plt.plot(dates, prices, marker="o", linestyle="-", color="blue")
#
# # Formatting date labels
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
# plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))
#
# plt.xlabel("Date")
# plt.ylabel("Stock Price (USD)")
# plt.title("Stock Price Over Time")
# plt.show()
# ```
# ✅ **Key Features:**
# - **`mdates.DateFormatter('%b %d')`** → Converts dates to readable format (e.g., **Jan 01, Jan 02**).
# - **`gca().xaxis.set_major_locator()`** → Controls how often dates appear.
#
# ---

# %% [markdown]
# Run !!

# %%
import matplotlib.dates as mdates
import datetime

# Sample stock data with dates
dates = [datetime.date(2023, 1, i) for i in range(1, 6)]
prices = [120, 125, 130, 128, 135]

plt.figure(figsize=(8,5))  # Set figure size
plt.plot(dates, prices, marker="o", linestyle="-", color="blue")

# Formatting date labels
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))

plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("Stock Price Over Time")
plt.show()

# %% [markdown]
# ## **📌 Summary**
# ✔ **Matplotlib is essential for financial plotting.**
# ✔ **Basic plot components include figure, axes, labels, title, legend, and grid.**
# ✔ **Customizing plots enhances readability and insights.**
# ✔ **Line plots, bar charts, and scatter plots are key financial tools.**
# ✔ **Handling financial time-series data is crucial for stock market analysis.**
#
# ---

# %% [markdown]
# ## **🟢 3. Advanced Matplotlib Features**
#
# ---
#
# ### **🔹 Creating Multiple Plots in One Figure (`subplots`)**
# Sometimes, we need to visualize multiple **financial insights in a single figure**. This is useful for **comparing different stocks, revenue vs. expenses, or stock trends over time**.
#
# #### **📌 Example: Plotting Stock Prices for Multiple Companies**
# ```python
# import matplotlib.pyplot as plt
#
# # Sample data for three stocks
# days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
# stock_A = [120, 125, 130, 128, 135]
# stock_B = [115, 118, 125, 127, 132]
# stock_C = [90, 95, 100, 102, 110]
#
# # Creating subplots (2 rows, 2 columns)
# fig, axes = plt.subplots(2, 2, figsize=(10, 6))
#
# # Line plots for each stock
# axes[0, 0].plot(days, stock_A, marker="o", color="blue")
# axes[0, 0].set_title("Stock A Prices")
#
# axes[0, 1].plot(days, stock_B, marker="s", color="red")
# axes[0, 1].set_title("Stock B Prices")
#
# axes[1, 0].plot(days, stock_C, marker="d", color="green")
# axes[1, 0].set_title("Stock C Prices")
#
# # Hiding empty subplot (since we have only 3 stocks)
# axes[1, 1].axis("off")
#
# plt.tight_layout()
# plt.show()
# ```
#
# ✅ **Key Features:**
# - `fig, axes = plt.subplots(2, 2, figsize=(10,6))` → Creates a 2x2 grid of plots.
# - `axes[row, col].plot()` → Selects each subplot for individual data.
# - `plt.tight_layout()` → Adjusts spacing between plots.
#
# ---

# %% [markdown]
# Run !!

# %%
import matplotlib.pyplot as plt

# Sample data for three stocks
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
stock_A = [120, 125, 130, 128, 135]
stock_B = [115, 118, 125, 127, 132]
stock_C = [90, 95, 100, 102, 110]

# Creating subplots (2 rows, 2 columns)
fig, axes = plt.subplots(2, 2, figsize=(10, 6))

# Line plots for each stock
axes[0, 0].plot(days, stock_A, marker="o", color="blue")
axes[0, 0].set_title("Stock A Prices")

axes[0, 1].plot(days, stock_B, marker="s", color="red")
axes[0, 1].set_title("Stock B Prices")

axes[1, 0].plot(days, stock_C, marker="d", color="green")
axes[1, 0].set_title("Stock C Prices")

# Hiding empty subplot (since we have only 3 stocks)
axes[1, 1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **🔹 Bar Charts for Financial Comparisons**
# Bar charts are useful to **compare financial data** such as:
# - **Stock performance across multiple companies**
# - **Quarterly revenue comparisons**
# - **Expense vs. revenue analysis**
#
# #### **📌 Example: Comparing Company Revenue**
# ```python
# import numpy as np
#
# companies = ["Apple", "Microsoft", "Google", "Amazon"]
# revenues = [250, 280, 220, 310]  # Revenue in billion USD
#
# plt.figure(figsize=(8, 5))  # Set figure size
# plt.bar(companies, revenues, color=["blue", "green", "red", "purple"])
#
# # Adding title and labels
# plt.xlabel("Company")
# plt.ylabel("Revenue (Billion USD)")
# plt.title("Quarterly Revenue Comparison")
# plt.show()
# ```
#
# ✅ **Key Features:**
# - **`plt.bar()`** → Creates a bar chart.
# - **Custom colors for bars** make the visualization more meaningful.
# - **Good for comparing multiple financial entities.**
#
# ---

# %% [markdown]
# Run !!

# %%
import numpy as np

companies = ["Apple", "Microsoft", "Google", "Amazon"]
revenues = [250, 280, 220, 310]  # Revenue in billion USD

plt.figure(figsize=(8, 5))  # Set figure size
plt.bar(companies, revenues, color=["blue", "green", "red", "purple"])

# Adding title and labels
plt.xlabel("Company")
plt.ylabel("Revenue (Billion USD)")
plt.title("Quarterly Revenue Comparison")
plt.show()

# %% [markdown]
# ### **🔹 Histograms for Stock Price Distributions**
# Histograms help **analyze the frequency of stock prices within a range**, which is useful for:
# - **Understanding market volatility**
# - **Assessing the risk of a stock**
#
# #### **📌 Example: Analyzing Stock Price Distribution**
# ```python
# import numpy as np
#
# # Simulated daily stock price changes
# stock_prices = np.random.normal(loc=150, scale=15, size=100)  # Mean price = 150, Volatility = 15
#
# plt.hist(stock_prices, bins=10, color="skyblue", edgecolor="black")
#
# plt.xlabel("Stock Price Range")
# plt.ylabel("Frequency")
# plt.title("Stock Price Distribution")
# plt.show()
# ```
#
# ✅ **Key Features:**
# - **`np.random.normal()`** → Generates random price movements around a mean.
# - **`plt.hist()`** → Creates a histogram.
# - **Histogram shape helps analyze stock volatility.**
#
# ---

# %% [markdown]
# Run !!

# %%
import numpy as np

# Simulated daily stock price changes
stock_prices = np.random.normal(loc=150, scale=15, size=100)  # Mean price = 150, Volatility = 15

plt.hist(stock_prices, bins=10, color="skyblue", edgecolor="black")

plt.xlabel("Stock Price Range")
plt.ylabel("Frequency")
plt.title("Stock Price Distribution")
plt.show()

# %% [markdown]
# ### **🔹 Box Plots for Analyzing Stock Volatility**
# Box plots (also called **whisker plots**) are useful for:
# - **Identifying outliers in stock prices**
# - **Understanding price variations**
# - **Detecting stock volatility over time**
#
# #### **📌 Example: Comparing Stock Volatility**
# ```python
# import seaborn as sns
#
# # Sample stock price data
# stock_data = {
#     "Company": ["Apple"]*10 + ["Google"]*10 + ["Microsoft"]*10,
#     "Price": np.concatenate([
#         np.random.normal(150, 10, 10),  # Apple
#         np.random.normal(280, 20, 10),  # Google
#         np.random.normal(220, 15, 10)   # Microsoft
#     ])
# }
#
# import pandas as pd
# df = pd.DataFrame(stock_data)
#
# # Creating the box plot
# sns.boxplot(x="Company", y="Price", data=df)
# plt.title("Stock Price Volatility")
# plt.show()
# ```
#
# ✅ **Key Features:**
# - **Box plots show median stock prices, interquartile range, and outliers.**
# - **Used for comparing stock price volatility across multiple companies.**
#
# ---

# %% [markdown]
# Run !!

# %%
import seaborn as sns

# Sample stock price data
stock_data = {
    "Company": ["Apple"]*10 + ["Google"]*10 + ["Microsoft"]*10,
    "Price": np.concatenate([
        np.random.normal(150, 10, 10),  # Apple
        np.random.normal(280, 20, 10),  # Google
        np.random.normal(220, 15, 10)   # Microsoft
    ])
}

import pandas as pd
df = pd.DataFrame(stock_data)

# Creating the box plot
sns.boxplot(x="Company", y="Price", data=df)
plt.title("Stock Price Volatility")
plt.show()

# %% [markdown]
# ## **📌 Summary**
# ✔ **Matplotlib's advanced features help analyze stock trends, volatility, and comparisons.**
# ✔ **Subplots allow visualization of multiple financial trends in one figure.**
# ✔ **Bar charts are great for revenue or stock performance comparisons.**
# ✔ **Histograms analyze stock price distributions and market volatility.**
# ✔ **Box plots detect outliers and stock price fluctuations.**
#
# ---

# %% [markdown]
# ## **🟢 4. Introduction to Seaborn for Financial Visualization**
#
# ---
#
# ### **🔹 Why Use Seaborn for Financial Analysis?**
# Seaborn is built on top of **Matplotlib** and provides **easier, more visually appealing** plots for **statistical and financial analysis**.
#
# #### **📌 Key Benefits for Finance:**
# ✔ **Automatically enhances plots** with themes and color palettes.
# ✔ **Simplifies complex visualizations** such as **heatmaps, pair plots, and violin plots**.
# ✔ **Seamlessly integrates with Pandas DataFrames**, making it easier to work with stock and financial data.
#
# ---
#
# ### **🔹 Seaborn vs. Matplotlib: When to Use Each?**
# | **Feature** | **Matplotlib** | **Seaborn** |
# |------------|--------------|-------------|
# | **Customization** | High (manual styling) | Automatic with built-in themes |
# | **Ease of Use** | More coding effort required | Simpler syntax for complex plots |
# | **Best Use Cases** | General plots (lines, bars, histograms) | Statistical & financial data analysis (heatmaps, box plots) |
# | **Integration with Pandas** | Requires manual processing | Works seamlessly with Pandas DataFrames |
#
# ✅ **Matplotlib is great for basic and customized charts.**
# ✅ **Seaborn is better for complex financial insights and statistics.**
#
# ---
#
# ### **🔹 Setting Up Seaborn in Python**
# To use Seaborn, install it first:
# ```python
# !pip install seaborn
# ```
# Then, import it in your script:
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```
#
# ---
#
# ### **🔹 Setting Themes and Color Palettes**
# Seaborn allows you to **apply themes** that enhance the appearance of plots.
#
# #### **📌 Applying Different Seaborn Themes**
# ```python
# sns.set_theme(style="darkgrid")  # Other styles: whitegrid, ticks, dark, white
# ```
# ✅ **Popular themes:**
# - `"darkgrid"` (best for financial plots)
# - `"whitegrid"` (good for reports)
# - `"dark"` (minimalist)
#
# ---
#
# ### **🔹 Creating Simple Seaborn Plots for Financial Data**
# #### **📌 Example: Stock Price Trends Using Seaborn**
# ```python
# import seaborn as sns
# import pandas as pd
#
# # Sample financial data
# data = pd.DataFrame({
#     "Days": ["Mon", "Tue", "Wed", "Thu", "Fri"],
#     "Price": [120, 125, 130, 128, 135]
# })
#
# # Line plot with Seaborn
# sns.set_theme(style="darkgrid")
# sns.lineplot(x="Days", y="Price", data=data, marker="o")
# plt.title("Stock Price Trend")
# plt.show()
# ```
#
# ✅ **Key Features:**
# - **Easier syntax** compared to Matplotlib.
# - **Seaborn automatically applies styling** (e.g., grid background).
# - **Great for visualizing stock trends over time.**
#
# ---

# %% [markdown]
# Run !!

# %%
import seaborn as sns
import pandas as pd

# Sample financial data
data = pd.DataFrame({
    "Days": ["Mon", "Tue", "Wed", "Thu", "Fri"],
    "Price": [120, 125, 130, 128, 135]
})

# Line plot with Seaborn
sns.set_theme(style="darkgrid")
sns.lineplot(x="Days", y="Price", data=data, marker="o")
plt.title("Stock Price Trend")
plt.show()

# %% [markdown]
# ### **🔹 Customizing Seaborn Plots**
# Seaborn provides **default aesthetics**, but you can customize:
# ✔ **Color Palettes:** `sns.color_palette("coolwarm")`
# ✔ **Axis Formatting:** `plt.xticks(rotation=45)`
# ✔ **Markers & Line Styles:** `sns.lineplot(marker="s", linestyle="dashed")`
#
# ---
#
# ## **📌 Summary**
# ✔ **Seaborn makes financial data visualization easier and more elegant.**
# ✔ **Themes and color palettes improve readability.**
# ✔ **Works seamlessly with Pandas DataFrames for financial datasets.**
# ✔ **Better suited for correlation analysis, trend identification, and distribution analysis.**
#
# ---

# %% [markdown]
# ## **📌 Enhancing Seaborn Visualizations with Themes and Color Palettes**
#
# ## **🔹 Why Use Seaborn Themes in Finance?**
# Seaborn provides **predefined themes** that help create **clear, professional, and visually appealing charts** with **minimal effort.**
#
# ✅ **Benefits of Themes in Financial Visualization:**
# ✔ **Consistent Styling** → Useful for financial reports and dashboards.
# ✔ **Improves Readability** → Easier to analyze trends and patterns.
# ✔ **Professional Presentation** → Well-structured visuals for business insights.
#
# ---
#
# ## **🔹 Setting Seaborn Themes for Financial Visuals**
# Seaborn provides **five built-in themes** that can be applied globally to all plots.
#
# ### **📌 Available Seaborn Themes**
# | **Theme Name**  | **Best Use Case in Finance** |
# |----------------|----------------------------|
# | `"darkgrid"`   | Best for **time-series stock analysis** |
# | `"whitegrid"`  | Suitable for **comparing financial performance** |
# | `"dark"`       | High contrast for **trading insights and stock trends** |
# | `"white"`      | Minimalist, best for **formal reports and presentations** |
# | `"ticks"`      | Good for **comparing investment risks and returns** |
#
# ### **📌 Example: Applying a Seaborn Theme**
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Setting Seaborn theme for financial visualization
# sns.set_theme(style="darkgrid")  # Best for stock market analysis
#
# # Sample stock price data
# days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
# prices = [120, 125, 130, 128, 135]
#
# # Creating a time-series line plot with a theme
# sns.lineplot(x=days, y=prices, marker="o", color="blue")
# plt.title("Stock Price Trend with Seaborn Theme")
# plt.xlabel("Days")
# plt.ylabel("Stock Price (USD)")
# plt.show()
# ```
# ✅ **Key Features:**
# - `sns.set_theme(style="darkgrid")` → Applies a professional finance-friendly theme.
# - **Themes enhance clarity and interpretation of financial trends.**
#
# ---

# %% [markdown]
# Run !!

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Setting Seaborn theme for financial visualization
sns.set_theme(style="ticks")  #darkgrid # Best for stock market analysis

# Sample stock price data
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
prices = [120, 125, 130, 128, 135]

# Creating a time-series line plot with a theme
sns.lineplot(x=days, y=prices, marker="o", color="blue")
plt.title("Stock Price Trend with Seaborn Theme")
plt.xlabel("Days")
plt.ylabel("Stock Price (USD)")
plt.show()

# %% [markdown]
# ## **🔹 Customizing Seaborn Color Palettes for Financial Data**
# In finance, **color-coding different assets, sectors, and trends** improves clarity and decision-making.
#
# ### **📌 Available Seaborn Color Palettes**
# | **Palette**  | **Best Use Case in Finance** |
# |-------------|---------------------------|
# | `"deep"`    | Standard finance reports |
# | `"muted"`   | Subtle, ideal for professional reports |
# | `"bright"`  | High-contrast financial insights |
# | `"dark"`    | Best for trading and market analysis |
# | `"colorblind"` | Ensures accessibility for all users |
#
# ### **📌 Example: Applying a Custom Color Palette**
# ```python
# # Applying a custom color palette
# sns.set_palette("muted")
#
# # Sample financial data
# sectors = ["Tech", "Health", "Finance", "Energy"]
# returns = [8.5, 5.2, 7.1, 4.3]
#
# # Creating a bar plot with custom colors
# sns.barplot(x=sectors, y=returns)
# plt.title("Stock Market Sector Performance")
# plt.ylabel("Average Returns (%)")
# plt.show()
# ```
# ✅ **Key Features:**
# - **Using different colors enhances the distinction between financial categories.**
# - **The color palette improves visualization consistency in reports and dashboards.**
#
# ---

# %% [markdown]
# Run !!

# %%
# Applying a custom color palette
sns.set_palette("muted")

# Sample financial data
sectors = ["Tech", "Health", "Finance", "Energy"]
returns = [8.5, 5.2, 7.1, 4.3]

# Creating a bar plot with custom colors
sns.barplot(x=sectors, y=returns)
plt.title("Stock Market Sector Performance")
plt.ylabel("Average Returns (%)")
plt.show()

# %% [markdown]
# # **📌 Working with Seaborn’s Built-in Datasets**
# Seaborn comes with **preloaded datasets**, which are useful for **practicing financial visualizations** before applying them to real-world data.
#
# ✅ **Why Use Built-in Datasets?**
# ✔ **Saves time** → No need to download financial data for testing.
# ✔ **Great for learning** → Helps understand Seaborn’s features.
# ✔ **Standardized format** → Works well with financial models.
#
# ### **📌 Example: Loading a Seaborn Dataset**
# ```python
# import seaborn as sns
#
# # Load a built-in dataset
# df = sns.load_dataset("titanic")  # Example dataset
#
# # Display first few rows
# df.head()
# ```
# ✅ **Use Case:**
# - Before using **real stock market data**, we can practice with **Seaborn’s datasets**.
#
# ---

# %% [markdown]
# Run !!

# %%
import seaborn as sns

# Load a built-in dataset
df = sns.load_dataset("titanic")  # Example dataset

# Display first few rows
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # **📌 Saving and Exporting Financial Plots**
# Financial analysts often need to **save and share** their **visualizations** in **reports, presentations, and websites.**
#
# ## **🔹 Supported Formats**
# | **Format** | **Best Use Case** |
# |------------|------------------|
# | **PNG**    | Web applications, presentations |
# | **PDF**    | High-quality financial reports |
# | **SVG**    | Vector graphics for professional use |
# | **JPG**    | Social media and general sharing |
#
# ## **🔹 Example: Saving a Stock Price Chart**
# ```python
# plt.figure(figsize=(8, 5))
# sns.lineplot(x=days, y=prices, marker="o", color="blue")
# plt.title("Stock Price Trend")
#
# # Save the figure in different formats
# plt.savefig("stock_price.png", dpi=300)  # High-resolution PNG
# plt.savefig("stock_price.pdf")  # Save as PDF
# plt.savefig("stock_price.svg")  # Save as SVG for vector graphics
# plt.show()
# ```
# ✅ **Key Features:**
# - `plt.savefig("filename.png", dpi=300)` → Saves a **high-quality PNG image**.
# - `plt.savefig("filename.pdf")` → Saves as a **PDF** for reports.
# - `plt.savefig("filename.svg")` → Saves in **SVG format** for professional use.
#
# ---

# %% [markdown]
# Run !!

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x=days, y=prices, marker="o", color="blue")
plt.title("Stock Price Trend")

# Save the figure in different formats
plt.savefig("stock_price.png", dpi=300)  # High-resolution PNG
plt.savefig("stock_price.pdf")  # Save as PDF
plt.savefig("stock_price.svg")  # Save as SVG for vector graphics
plt.show()

# %% [markdown]
# ## **🔹 Handling Missing Data in Financial Visualization**
# Sometimes, stock market data has **missing prices or returns**.
# Seaborn and Matplotlib provide **methods to handle missing values** before visualization.
#
# #### **📌 Example: Filling Missing Values Before Plotting**
# ```python
# df["Stock Price"].fillna(df["Stock Price"].mean(), inplace=True)  # Replace missing prices with the average
# sns.lineplot(x=df["Date"], y=df["Stock Price"], marker="o")
# plt.show()
# ```
# ✅ **Key Features:**
# - Prevents missing values from **affecting financial analysis**.
# - **Ensures accurate visual representation** of data.
#
# ---

# %% [markdown]
# Run !!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Generate dummy data
np.random.seed(42)
dates = pd.date_range(start="2024-01-01", periods=30, freq="D")
stock_prices = np.random.uniform(low=100, high=200, size=len(dates))
stock_prices[5] = np.nan  # Introduce a missing value
stock_prices[15] = np.nan  # Another missing value

# Create DataFrame
df = pd.DataFrame({"Date": dates, "Stock Price": stock_prices})

# Fix: Assign the result of fillna back to the column
df["Stock Price"] = df["Stock Price"].fillna(df["Stock Price"].mean())

# Plot the data
sns.lineplot(x=df["Date"], y=df["Stock Price"], marker="o")
plt.xticks(rotation=45)
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.title("Stock Price Over Time (Dummy Data)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## **🔹 Interactive Financial Visualizations**
# Although we focused on **Matplotlib and Seaborn**, adding **interactive visualizations** using **Plotly or Streamlit** would make the analysis **more user-friendly**.
#
# #### **📌 Example: Adding Interactive Features in Seaborn**
# ```python
# import plotly.express as px
#
# # Sample data
# fig = px.line(df, x="Date", y="Stock Price", title="Stock Price Over Time", markers=True)
#
# # Show interactive chart
# fig.show()
# ```
# ✅ **Key Features:**
# - Interactive **hover effects**.
# - Allows **zooming in on financial trends**.
# - Improves **user engagement in financial dashboards**.
#
# ---

# %% [markdown]
# Run !!

# %%
import plotly.express as px

# Sample data
fig = px.line(df, x="Date", y="Stock Price", title="Stock Price Over Time", markers=True)

# Show interactive chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **🟢 5. Advanced Seaborn Visualizations**
#
# ---
#
# ### **🔹 Heatmaps for Correlation Analysis**
# A **heatmap** is used to **analyze relationships between multiple financial assets** (stocks, cryptocurrencies, etc.).
# - Helps **identify correlations** between stocks.
# - Used in **portfolio diversification** and **risk assessment**.
#
# #### **📌 Example: Stock Correlation Matrix**
# ```python
# import seaborn as sns
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Sample stock data
# stock_data = pd.DataFrame({
#     "AAPL": np.random.randint(100, 200, 10),
#     "GOOGL": np.random.randint(1500, 2000, 10),
#     "TSLA": np.random.randint(500, 900, 10),
#     "MSFT": np.random.randint(200, 400, 10)
# })
#
# # Compute correlation matrix
# corr_matrix = stock_data.corr()
#
# # Plot heatmap
# plt.figure(figsize=(8,6))
# sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
# plt.title("Stock Correlation Heatmap")
# plt.show()
# ```
#
# ✅ **Key Features:**
# - `corr_matrix = stock_data.corr()` → Calculates correlation between stocks.
# - `sns.heatmap()` → Creates a heatmap for better visualization.
# - **Red means negative correlation**, **blue means positive correlation**.
#
# ---

# %% [markdown]
# Run !!

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample stock data
stock_data = pd.DataFrame({
    "AAPL": np.random.randint(100, 200, 10),
    "GOOGL": np.random.randint(1500, 2000, 10),
    "TSLA": np.random.randint(500, 900, 10),
    "MSFT": np.random.randint(200, 400, 10)
})

# Compute correlation matrix
corr_matrix = stock_data.corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Stock Correlation Heatmap")
plt.show()

# %% [markdown]
# ### **🔹 Pair Plots for Multi-Stock Comparisons**
# A **pair plot** is useful for:
# - **Comparing multiple stocks at once**.
# - Identifying **relationships between different assets**.
#
# #### **📌 Example: Comparing Stocks Using a Pair Plot**
# ```python
# sns.pairplot(stock_data)
# plt.show()
# ```
# ✅ **Key Features:**
# - Helps find **linear or non-linear relationships** between stocks.
# - Useful for **portfolio risk analysis**.
#
# ---

# %% [markdown]
# Run !!

# %%
sns.pairplot(stock_data)
plt.show()

# %% [markdown]
# ### **🔹 Violin & Box Plots for Financial Data Distributions**
# A **violin plot** combines a **box plot and a density plot** to show:
# - **Stock price variations** over time.
# - **Outliers in financial data**.
#
# #### **📌 Example: Stock Price Distribution**
# ```python
# sns.violinplot(data=stock_data)
# plt.title("Stock Price Distribution")
# plt.show()
# ```
#
# ✅ **Key Features:**
# - **Wider areas indicate more frequent price ranges**.
# - **Narrow areas indicate rare stock prices**.
# - **Box inside the violin plot shows median and quartiles**.
#
# ---

# %% [markdown]
# Run !!

# %%
sns.violinplot(data=stock_data)
plt.title("Stock Price Distribution")
plt.show()

# %% [markdown]
# ### **🔹 Regression Plots for Stock Trend Predictions**
# A **regression plot** shows:
# - **Relationship between two financial variables**.
# - **Stock price trends and potential predictions**.
#
# #### **📌 Example: Stock Price vs Trading Volume**
# ```python
# # Sample data
# stock_data["Volume"] = np.random.randint(1000, 5000, 10)
#
# # Regression plot
# sns.regplot(x="Volume", y="AAPL", data=stock_data)
# plt.title("AAPL Stock Price vs Trading Volume")
# plt.show()
# ```
#
# ✅ **Key Features:**
# - Shows **trend lines** between **stock price and volume**.
# - Useful for **predicting stock movements**.

# %% [markdown]
# Run !!

# %%
# Sample data
stock_data["Volume"] = np.random.randint(1000, 5000, 10)

# Regression plot
sns.regplot(x="Volume", y="AAPL", data=stock_data)
plt.title("AAPL Stock Price vs Trading Volume")
plt.show()

# %% [markdown]
# ---
#
# ## **📌 Summary**
# ✔ **Heatmaps** identify stock correlations.
# ✔ **Pair plots** compare multiple financial assets.
# ✔ **Violin plots** analyze stock price distributions.
# ✔ **Regression plots** show stock trends for prediction.
#
# ---

# %% [markdown]
# ## **🟢 6. Visualizing Financial Insights & Trends**
#
# ---
#
# ### **🔹 Time-Series Plots for Stock Movements**
# Time-series plots are crucial for **analyzing stock price trends** over time.
# They help in **identifying patterns, detecting volatility, and predicting future prices**.
#
# #### **📌 Example: Stock Price Over Time**
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Generate sample time-series stock data
# dates = pd.date_range(start="2024-01-01", periods=30, freq="D")
# stock_prices = np.cumsum(np.random.randn(30) * 2) + 150  # Simulating stock price fluctuations
#
# # Create a DataFrame
# df = pd.DataFrame({"Date": dates, "Stock Price": stock_prices})
#
# # Plot stock price trend
# plt.figure(figsize=(10, 5))
# sns.lineplot(x="Date", y="Stock Price", data=df, marker="o")
# plt.xticks(rotation=45)
# plt.title("Stock Price Trend Over 30 Days")
# plt.xlabel("Date")
# plt.ylabel("Stock Price (USD)")
# plt.show()
# ```
# ✅ **Key Features:**
# - `pd.date_range()` → Creates a series of **dates for stock prices**.
# - `np.cumsum()` → Simulates **random stock price changes**.
# - `sns.lineplot()` → Creates a **smooth time-series plot**.
#
# ---

# %% [markdown]
# Run !!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate sample time-series stock data
dates = pd.date_range(start="2024-01-01", periods=30, freq="D")
stock_prices = np.cumsum(np.random.randn(30) * 2) + 150  # Simulating stock price fluctuations

# Create a DataFrame
df = pd.DataFrame({"Date": dates, "Stock Price": stock_prices})

# Plot stock price trend
plt.figure(figsize=(10, 5))
sns.lineplot(x="Date", y="Stock Price", data=df, marker="o")
plt.xticks(rotation=45)
plt.title("Stock Price Trend Over 30 Days")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.show()

# %% [markdown]
# ### **🔹 Moving Averages & Trend Analysis**
# Moving averages help in:
# - **Smoothing price fluctuations** to detect real trends.
# - **Predicting potential future movements**.
#
# #### **📌 Example: Stock Price with Moving Averages**
# ```python
# df["7-Day MA"] = df["Stock Price"].rolling(window=7).mean()  # 7-day moving average
#
# plt.figure(figsize=(10, 5))
# sns.lineplot(x="Date", y="Stock Price", data=df, marker="o", label="Stock Price")
# sns.lineplot(x="Date", y="7-Day MA", data=df, marker="s", linestyle="dashed", label="7-Day Moving Average")
#
# plt.xticks(rotation=45)
# plt.title("Stock Price with Moving Average")
# plt.xlabel("Date")
# plt.ylabel("Stock Price (USD)")
# plt.legend()
# plt.show()
# ```
# ✅ **Key Features:**
# - `rolling(window=7).mean()` → Calculates **7-day moving average**.
# - Helps **smooth price fluctuations** and detect **trends**.
#
# ---

# %%
df["7-Day MA"] = df["Stock Price"].rolling(window=7).mean()  # 7-day moving average

plt.figure(figsize=(10, 5))
sns.lineplot(x="Date", y="Stock Price", data=df, marker="o", label="Stock Price")
sns.lineplot(x="Date", y="7-Day MA", data=df, marker="s", linestyle="dashed", label="7-Day Moving Average")

plt.xticks(rotation=45)
plt.title("Stock Price with Moving Average")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.legend()
plt.show()

# %% [markdown]
# ### **🔹 Market Volatility Analysis Using Histograms**
# A **histogram** helps analyze:
# - **The frequency of stock price changes**.
# - **How volatile a stock is** over time.
#
# #### **📌 Example: Stock Volatility Analysis**
# ```python
# plt.figure(figsize=(8, 5))
# sns.histplot(df["Stock Price"], bins=10, kde=True, color="purple")
# plt.title("Stock Price Distribution")
# plt.xlabel("Stock Price")
# plt.ylabel("Frequency")
# plt.show()
# ```
# ✅ **Key Features:**
# - **KDE line (kernel density estimate)** shows **the smooth probability distribution** of stock prices.
# - Helps detect **highly volatile stocks**.
#
# ---

# %% [markdown]
# Run !!

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["Stock Price"], bins=10, kde=True, color="purple")
plt.title("Stock Price Distribution")
plt.xlabel("Stock Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### **🔹 Investment Risk Assessment Using Box Plots**
# Box plots help:
# - **Detect outliers in stock prices**.
# - **Identify stock stability vs. high volatility**.
#
# #### **📌 Example: Comparing Volatility in Multiple Stocks**
# ```python
# # Simulated stock data
# stock_data = pd.DataFrame({
#     "Company": ["Apple"]*30 + ["Google"]*30 + ["Microsoft"]*30,
#     "Stock Price": np.concatenate([
#         np.random.normal(150, 10, 30),  # Apple
#         np.random.normal(280, 20, 30),  # Google
#         np.random.normal(220, 15, 30)   # Microsoft
#     ])
# })
#
# # Box plot for stock volatility
# plt.figure(figsize=(8,5))
# sns.boxplot(x="Company", y="Stock Price", data=stock_data)
# plt.title("Stock Price Volatility Across Companies")
# plt.show()
# ```
# ✅ **Key Features:**
# - **Longer boxes indicate higher volatility**.
# - **Dots outside the box indicate outliers (sharp price changes)**.
#
# ---

# %% [markdown]
# Run !!

# %%
# Simulated stock data
stock_data = pd.DataFrame({
    "Company": ["Apple"]*30 + ["Google"]*30 + ["Microsoft"]*30,
    "Stock Price": np.concatenate([
        np.random.normal(150, 10, 30),  # Apple
        np.random.normal(280, 20, 30),  # Google
        np.random.normal(220, 15, 30)   # Microsoft
    ])
})

# Box plot for stock volatility
plt.figure(figsize=(8,5))
sns.boxplot(x="Company", y="Stock Price", data=stock_data)
plt.title("Stock Price Volatility Across Companies")
plt.show()

# %% [markdown]
# ### **🔹 Combining Multiple Insights into a Dashboard**
# A **multi-plot dashboard** provides a **complete picture of stock performance**.
#
# #### **📌 Example: Dashboard for Financial Insights**
# ```python
# fig, axes = plt.subplots(2, 2, figsize=(12, 8))
#
# # Line plot for stock trend
# sns.lineplot(x="Date", y="Stock Price", data=df, marker="o", ax=axes[0, 0])
# axes[0, 0].set_title("Stock Price Trend")
#
# # Histogram for stock price distribution
# sns.histplot(df["Stock Price"], bins=10, kde=True, color="purple", ax=axes[0, 1])
# axes[0, 1].set_title("Stock Price Distribution")
#
# # Box plot for stock volatility
# sns.boxplot(x="Company", y="Stock Price", data=stock_data, ax=axes[1, 0])
# axes[1, 0].set_title("Stock Volatility Comparison")
#
# # Scatter plot for correlation
# sns.scatterplot(x="Stock Price", y="7-Day MA", data=df, ax=axes[1, 1])
# axes[1, 1].set_title("Stock Price vs Moving Average")
#
# plt.tight_layout()
# plt.show()
# ```
# ✅ **Key Features:**
# - **Combines multiple financial insights in one dashboard**.
# - **Time-series, histograms, box plots, and scatter plots** for better **investment decisions**.
#
# ---

# %% [markdown]
# Run !!

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Line plot for stock trend
sns.lineplot(x="Date", y="Stock Price", data=df, marker="o", ax=axes[0, 0])
axes[0, 0].set_title("Stock Price Trend")

# Histogram for stock price distribution
sns.histplot(df["Stock Price"], bins=10, kde=True, color="purple", ax=axes[0, 1])
axes[0, 1].set_title("Stock Price Distribution")

# Box plot for stock volatility
sns.boxplot(x="Company", y="Stock Price", data=stock_data, ax=axes[1, 0])
axes[1, 0].set_title("Stock Volatility Comparison")

# Scatter plot for correlation
sns.scatterplot(x="Stock Price", y="7-Day MA", data=df, ax=axes[1, 1])
axes[1, 1].set_title("Stock Price vs Moving Average")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **📌 Summary**
# ✔ **Time-series plots** track stock price movements.
# ✔ **Moving averages** smooth fluctuations to reveal trends.
# ✔ **Histograms** analyze market volatility.
# ✔ **Box plots** assess investment risk.
# ✔ **Multi-plot dashboards** provide **comprehensive stock insights**.
#
# ---

# %% [markdown]
# # **📌 Step-by-Step Guide: Using Real-World Stock Data from Yahoo Finance**
#
# ✔ **Fetch live stock data from Yahoo Finance**
# ✔ **Extract adjusted close prices & handle missing data**
# ✔ **Plot stock trends, correlations, and daily returns**
# ✔ **Build a multi-plot financial dashboard**
#
# ---
#
# ### **✅ Step 1: Install & Import Required Libraries**
# ```python
# # Install required libraries (only needed once)
# !pip install yfinance pandas matplotlib seaborn
#
# # Import necessary libraries
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
# ✅ **Explanation:**
# - `yfinance` → Fetches **real-time stock data**.
# - `pandas` → Handles **data processing**.
# - `matplotlib` & `seaborn` → Used for **data visualization**.
#
# ---
#
# ### **✅ Step 2: Fetch Stock Market Data from Yahoo Finance**
# ```python
# # Define stock tickers for analysis
# stocks = ["AAPL", "GOOGL", "TSLA", "AMZN"]
#
# # Download stock data for the last 6 months
# stock_data = yf.download(stocks, start="2023-10-01", end="2024-04-01")
#
# # Display first 5 rows
# print("📌 Available Stock Data:")
# print(stock_data.head())
# ```
# ✅ **Explanation:**
# - Retrieves stock market data for **Apple, Google, Tesla, and Amazon**.
# - **Includes:** Open, High, Low, Close, Adjusted Close, and Volume.
#
# ✅ **Expected Output:**
# ```
# 📌 Available Stock Data:
#                   Open       High        Low      Close  Adj Close      Volume
# Date
# 2023-10-02  171.279999  173.449997  170.889999  172.699997  172.123456   59340000
# 2023-10-03  170.750000  172.429993  170.210007  171.100006  170.876543   46910000
# ...
# ```
#
# ---
#
# ### **✅ Step 3: Debug & Handle Missing Data**
# ```python
# # Print available columns in dataset
# print("\n📌 Available Columns in Dataset:")
# print(stock_data.columns)
#
# # Check if dataset is empty
# if stock_data.empty:
#     raise ValueError("🚨 No stock data retrieved! Check stock tickers and date range.")
# ```
# ✅ **Explanation:**
# - Prints available columns to check if `"Close"` or `"Adj Close"` is present.
# - Warns the user if **no stock data is found** (invalid tickers, wrong dates, etc.).
#
# ✅ **Expected Output:**
# ```
# 📌 Available Columns in Dataset:
# MultiIndex([('Open', 'AAPL'), ('High', 'AAPL'), ('Low', 'AAPL'), ('Close', 'AAPL'),
#             ('Open', 'GOOGL'), ('High', 'GOOGL'), ('Low', 'GOOGL'), ('Close', 'GOOGL')],
#            names=['Attribute', 'Ticker'])
# ```
#
# ---
#
# ### **✅ Step 4: Extract Adjusted Close Prices**
# ```python
# # Handle Multi-Level Column Format
# if isinstance(stock_data.columns, pd.MultiIndex):
#     adj_close = stock_data.xs("Close", axis=1, level=0)  # Extract Close prices
# else:
#     adj_close = stock_data.get("Close", pd.DataFrame())  # Extract Close prices safely
#
# # Ensure we have valid data
# if adj_close.empty:
#     raise ValueError("🚨 No 'Close' price data found! Check stock tickers and date range.")
#
# print("\n📌 Extracted Adjusted Close Prices:")
# print(adj_close.head())
# ```
# ✅ **Explanation:**
# - **Handles multi-index data** if Yahoo Finance returns nested columns.
# - **Extracts closing prices** safely (fallbacks if needed).
# - **Throws an error if stock data is missing**.
#
# ✅ **Expected Output:**
# ```
# 📌 Extracted Adjusted Close Prices:
#                   AAPL       GOOGL       TSLA       AMZN
# Date
# 2023-10-02  172.699997  2817.250000  870.239990  3367.250000
# 2023-10-03  171.100006  2802.110107  855.080017  3325.889893
# ...
# ```
#
# ---
#
# ### **✅ Step 5: Plot Stock Price Trends Over Time**
# ```python
# # Plot stock price trends over time
# plt.figure(figsize=(12,6))
#
# for stock in stocks:
#     sns.lineplot(data=adj_close, x=adj_close.index, y=stock, label=stock)
#
# plt.title("📊 Stock Price Trends Over 6 Months")
# plt.xlabel("Date")
# plt.ylabel("Stock Price (USD)")
# plt.legend()
# plt.xticks(rotation=45)
# plt.show()
# ```
# ✅ **Explanation:**
# - **Plots stock prices** for Apple, Google, Tesla, and Amazon.
# - Helps identify **bullish/bearish trends**.
#
# ✅ **Expected Output:**
# 📈 **Line chart showing stock prices fluctuating over time.**
#
# ---
#
# ### **✅ Step 6: Analyze Stock Volatility**
# ```python
# plt.figure(figsize=(10,6))
#
# # Plot stock price distributions
# for stock in stocks:
#     sns.histplot(adj_close[stock], kde=True, label=stock, alpha=0.5)
#
# plt.title("📊 Stock Price Distribution & Volatility")
# plt.xlabel("Stock Price (USD)")
# plt.legend()
# plt.show()
# ```
# ✅ **Explanation:**
# - **Visualizes stock price distributions**.
# - Helps determine **which stocks are more volatile**.
#
# ✅ **Expected Output:**
# 📊 **Histogram showing how often certain stock prices occurred.**
#
# ---
#
# ### **✅ Step 7: Compute & Plot Stock Correlations**
# ```python
# # Compute correlation matrix
# corr_matrix = adj_close.corr()
#
# # Create a heatmap
# plt.figure(figsize=(8,6))
# sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
# plt.title("📊 Stock Price Correlation Heatmap")
# plt.show()
# ```
# ✅ **Explanation:**
# - **Checks how stock prices move together** (correlations).
# - Helps **diversify investments** (strongly correlated stocks move together).
#
# ✅ **Expected Output:**
# 📊 **Heatmap with correlation values between stocks.**
# - **Red/Blue Colors** → Strong/Weak relationships.
#
# ---
#
# ### **✅ Step 8: Compute & Plot Daily Stock Returns**
# ```python
# # Compute daily percentage change
# daily_returns = adj_close.pct_change()
#
# # Display first few rows
# print("\n📌 Daily Stock Returns:")
# print(daily_returns.head())
#
# # Plot daily stock returns
# plt.figure(figsize=(12,6))
#
# for stock in stocks:
#     sns.lineplot(data=daily_returns, x=daily_returns.index, y=stock, label=stock)
#
# plt.title("📊 Daily Stock Returns Over 6 Months")
# plt.xlabel("Date")
# plt.ylabel("Daily Return (%)")
# plt.legend()
# plt.xticks(rotation=45)
# plt.show()
# ```
# ✅ **Explanation:**
# - **Calculates daily returns** to measure stock risk.
# - **Line chart shows stock volatility** over time.
#
# ✅ **Expected Output:**
# 📈 **Daily return trends for each stock.**
#
# ---
#
# ### **✅ Step 9: Build Financial Dashboard**
# ```python
# fig, axes = plt.subplots(2, 2, figsize=(12, 8))
#
# sns.lineplot(data=adj_close, x=adj_close.index, y="AAPL", ax=axes[0, 0])
# axes[0, 0].set_title("📊 AAPL Stock Price Trend")
#
# sns.histplot(adj_close["TSLA"], kde=True, color="purple", ax=axes[0, 1])
# axes[0, 1].set_title("📊 TSLA Stock Price Distribution")
#
# sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", ax=axes[1, 0])
# axes[1, 0].set_title("📊 Stock Correlation Matrix")
#
# sns.lineplot(data=daily_returns, x=daily_returns.index, y="AMZN", ax=axes[1, 1])
# axes[1, 1].set_title("📊 AMZN Daily Returns")
#
# plt.tight_layout()
# plt.show()
# ```
# ✅ **Explanation:**
# - Combines **price trends, correlations, distributions, and returns** into **one dashboard**.
#
# ✅ **Expected Output:**
# 📊 **Multi-plot dashboard summarizing stock trends.**
#
#
# ---
#
# # **📌 Summary: Step-by-Step Process for Using Yahoo Finance Data**
# ### ✅ **Step 1:** Install and import `yfinance`, `pandas`, `matplotlib`, `seaborn`.
# ### ✅ **Step 2:** Fetch **real-world stock data** using `yf.download()`.
# ### ✅ **Step 3:** Extract **Adjusted Close Prices** for accurate analysis.
# ### ✅ **Step 4:** Plot **stock price trends** over time using **Matplotlib & Seaborn**.
# ### ✅ **Step 5:** Analyze **stock volatility** using **histograms**.
# ### ✅ **Step 6:** Compute **stock market correlation matrix** using **heatmaps**.
# ### ✅ **Step 7:** Compare **stock performance** using **daily returns**.
# ### ✅ **Step 8:** Build a **multi-plot financial dashboard** summarizing insights.
#
# ---

# %% [markdown]
# Run !!

# %%
# 📌 Step 1: Install & Import Required Libraries
# !pip install yfinance pandas matplotlib seaborn

# %%
# Import necessary libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Function to Print Step Headings in Output
def print_heading(text):
    print("\n" + "="*50)
    print(f"📌 {text}")
    print("="*50)

# 📌 Step 2: Fetch Stock Market Data from Yahoo Finance
print_heading("Step 2: Fetching Real-World Stock Data")
stocks = ["AAPL", "GOOGL", "TSLA", "AMZN"]  # List of stock tickers

# Download stock data for the last 6 months
stock_data = yf.download(stocks, start="2023-10-01", end="2024-04-01")

# Display first 5 rows
print("📌 Available Stock Data:")
print(stock_data.head())

# 📌 Step 3: Debug & Handle Missing Data
print_heading("Step 3: Checking Available Columns & Handling Missing Data")

# Print available columns
print("📌 Available Columns in Dataset:")
print(stock_data.columns)

# Check if dataset is empty
if stock_data.empty:
    raise ValueError("🚨 No stock data retrieved! Check stock tickers and date range.")

# 📌 Step 4: Extract Adjusted Close Prices
print_heading("Step 4: Extracting Adjusted Close Prices")

# Handle Multi-Level Column Format
if isinstance(stock_data.columns, pd.MultiIndex):
    adj_close = stock_data.xs("Close", axis=1, level=0)  # Extract Close prices
else:
    adj_close = stock_data.get("Close", pd.DataFrame())  # Extract Close prices safely

# Ensure we have valid data
if adj_close.empty:
    raise ValueError("🚨 No 'Close' price data found! Check stock tickers and date range.")

# Display first few rows
print("📌 Extracted Adjusted Close Prices:")
print(adj_close.head())

# 📌 Step 5: Plot Stock Price Trends Over Time
print_heading("Step 5: Plotting Stock Price Trends Over Time")

plt.figure(figsize=(12,6))
for stock in stocks:
    sns.lineplot(data=adj_close, x=adj_close.index, y=stock, label=stock)
plt.title(" Stock Price Trends Over 6 Months")
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# 📌 Step 6: Analyze Stock Volatility
print_heading("Step 6: Analyzing Stock Price Volatility")

plt.figure(figsize=(10,6))
for stock in stocks:
    sns.histplot(adj_close[stock], kde=True, label=stock, alpha=0.5)
plt.title(" Stock Price Distribution & Volatility")
plt.xlabel("Stock Price (USD)")
plt.legend()
plt.show()

# 📌 Step 7: Compute & Plot Stock Correlations
print_heading("Step 7: Computing Stock Market Correlation Matrix")

# Compute correlation matrix
corr_matrix = adj_close.corr()

# Create a heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title(" Stock Price Correlation Heatmap")
plt.show()

# 📌 Step 8: Compute & Plot Daily Stock Returns
print_heading("Step 8: Computing Daily Stock Returns")

# Compute daily percentage change
daily_returns = adj_close.pct_change()

# Display first few rows
print("📌 Daily Stock Returns:")
print(daily_returns.head())

# Plot daily stock returns
plt.figure(figsize=(12,6))
for stock in stocks:
    sns.lineplot(data=daily_returns, x=daily_returns.index, y=stock, label=stock)
plt.title(" Daily Stock Returns Over 6 Months")
plt.xlabel("Date")
plt.ylabel("Daily Return (%)")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# 📌 Step 9: Build Financial Dashboard
print_heading("Step 9: Building Financial Dashboard")

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

sns.lineplot(data=adj_close, x=adj_close.index, y="AAPL", ax=axes[0, 0])
axes[0, 0].set_title(" AAPL Stock Price Trend")

sns.histplot(adj_close["TSLA"], kde=True, color="purple", ax=axes[0, 1])
axes[0, 1].set_title(" TSLA Stock Price Distribution")

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", ax=axes[1, 0])
axes[1, 0].set_title(" Stock Correlation Matrix")

sns.lineplot(data=daily_returns, x=daily_returns.index, y="AMZN", ax=axes[1, 1])
axes[1, 1].set_title("AMZN Daily Returns")

plt.tight_layout()
plt.show()

print_heading("✅ Analysis Complete! Your Stock Market Insights Are Ready! 🎯")
# Out:
# [                       0%                       ]
# ...
# 📌 Step 2: Fetching Real-World Stock Data
# ...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  4 of 4 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AAPL']: OperationalError('database is locked')
# 📌 Available Stock Data:
# Price      Adj Close Close                                     High  \
# Ticker          AAPL  AAPL        AMZN       GOOGL        TSLA AAPL
# Date
# 2023-10-02       NaN   NaN  129.460007  133.531601  251.600006  NaN
# 2023-10-03       NaN   NaN  124.720001  131.799866  246.529999  NaN
# 2023-10-04       NaN   NaN  127.000000  134.596512  261.160004  NaN
# 2023-10-05       NaN   NaN  125.959999  134.427307  260.049988  NaN
# 2023-10-06       NaN   NaN  127.959999  136.925385  260.529999  NaN
#
# Price                                           Low  ...              \
# ...
